# %%
import pyisomme

# %%
channel_1 = pyisomme.create_sample("1???????????????", t_range=(0,0.1,1000), y_range=(10,10), mode="linear", unit="m/(s*s)")
channel_1.data.plot()

channel_2 = pyisomme.create_sample("2???????????????", t_range=(0,0.1,700), y_range=(0,10), mode="linear", unit="m/(s*s)")
channel_2.data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Addition

# %%
channel_res = channel_1 + channel_2 + 10
channel_res.data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Subtraction

# %%
channel_res = channel_1 - channel_2 - 10
channel_res.data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Multiplication

# %%
channel_res = channel_1 * channel_2 * 2
channel_res.data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Division

# %%
channel_res = channel_1 / channel_2 / 2
channel_res.data.plot(ylim=(0,10))
# Out:
# D:\pyisomme\pyisomme\channel.py:202: RuntimeWarning: divide by zero encountered in true_divide
#   new_data = self.get_data(time_array) / other.get_data(time_array)
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Exponent

# %%
channel_res = channel_2**2
channel_res.data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>
