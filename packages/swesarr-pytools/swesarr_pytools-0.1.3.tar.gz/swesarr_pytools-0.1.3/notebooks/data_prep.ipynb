# %%
import sys
sys.path.append("/media/eviofekeze/extrastorage/packages/swesarr_pytool")
from swesarr_pytool.data_tools import ReadSwesarr

# %%
x_band = "../resources/swesarr_data/GRMCT1_13801_19005_010_191106_225_XX_01/GRMCT1_13801_19005_010_191106_09225VH_XX_01.tif"
flight_folder = "../resources/swesarr_data/GRMCT1_13801_19005_010_191106_225_XX_01"
lidar_data_path = "../resources/lidar_data/ASO_GrandMesa_2020Feb13_snowdepth_3m.tif"

swesarr_fall_v3 = "../resources/swesarr_data_v3/19004_011"
swesarr_winter_v3 = "../resources/swesarr_data_v3/20006_003"

swesarr_fall_v1 = "../resources/swesarr_data/GRMCT1_13801_19005_010_191106_225_XX_01"
swesarr_winter_v1 = "../resources/swesarr_data/GRMCT2_13802_20006_012_200210_225_XX_01"

# %%
import os
os.getcwd()
# Out:
# '/media/eviofekeze/extrastorage/packages/swesarr_pytool/notebooks'

# %%
example = ReadSwesarr(flight_path=flight_folder, version="v1")
example_list = example.get_data_files()
print(f"Folder List: {example_list}")
# Out:
# Folder List: ['GRMCT1_13801_19005_010_191106_13225VH_XX_01.tif', 'GRMCT1_13801_19005_010_191106_17225VH_XX_01.tif', 'GRMCT1_13801_19005_010_191106_09225VV_XX_01.tif', 'GRMCT1_13801_19005_010_191106_17225VV_XX_01.tif', 'GRMCT1_13801_19005_010_191106_13225VV_XX_01.tif', 'GRMCT1_13801_19005_010_191106_09225VH_XX_01.tif']

# %%
example_raster = example.get_swesarr_raster()
example_raster
# Out:
# <xarray.DataArray (band: 6, y: 3651, x: 2963)>
# dask.array<concatenate, shape=(6, 3651, 2963), dtype=float32, chunksize=(1, 1200, 1200), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) <U4 '13VH' '17VH' '09VV' '17VV' '13VV' '09VH'
#   * x            (x) float64 7.412e+05 7.412e+05 ... 7.471e+05 7.471e+05
#   * y            (y) float64 4.328e+06 4.328e+06 4.328e+06 ... 4.32e+06 4.32e+06
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    nan
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
example_df = example.get_swesarr_df()
example_df
# Out:
#                      y              x      F09VV      F09VH      F13VV  \
# 426673    4.327470e+06  741215.109977   0.000000   0.000000   0.000000
# 429636    4.327468e+06  741215.109977   0.000000   0.000000   0.000000
# 429637    4.327468e+06  741217.109977   0.000000   0.000000   0.000000
# 432599    4.327466e+06  741215.109977   0.000000   0.000000   0.000000
# 432600    4.327466e+06  741217.109977   0.000000   0.000000   0.000000
# ...                ...            ...        ...        ...        ...
# 10589389  4.320612e+06  746393.109977 -17.756666 -30.629366 -31.941320
# 10589390  4.320612e+06  746395.109977 -17.891167 -30.814734 -32.145603
# 10589391  4.320612e+06  746397.109977 -17.743111 -30.678053 -33.162926
# 10592352  4.320610e+06  746393.109977 -17.801363 -30.358782 -29.526028
# 10592353  4.320610e+06  746395.109977 -18.255501 -29.933887 -33.326679
#
#               F13VH      F17VV      F17VH
# 426673     0.000000   0.000000   0.000000
# 429636     0.000000   0.000000   0.000000
# 429637     0.000000   0.000000   0.000000
# 432599     0.000000   0.000000   0.000000
# 432600     0.000000   0.000000   0.000000
# ...             ...        ...        ...
# 10589389 -32.845257 -40.240311 -38.687332
# 10589390 -33.278454 -38.791313 -41.042126
# 10589391 -33.813126 -38.793060 -40.096455
# 10592352 -33.857082 -38.059433 -42.774803
# 10592353 -29.271967 -38.081070 -39.193199
#
# [2001519 rows x 8 columns]

# %%
x_example = ReadSwesarr(flight_path=flight_folder,version="v1")
x_example_raster = x_example.get_swesarr_raster()
x_example_raster
# Out:
# <xarray.DataArray (band: 6, y: 3651, x: 2963)>
# dask.array<concatenate, shape=(6, 3651, 2963), dtype=float32, chunksize=(1, 1200, 1200), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) <U4 '13VH' '17VH' '09VV' '17VV' '13VV' '09VH'
#   * x            (x) float64 7.412e+05 7.412e+05 ... 7.471e+05 7.471e+05
#   * y            (y) float64 4.328e+06 4.328e+06 4.328e+06 ... 4.32e+06 4.32e+06
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    nan
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
x_example = ReadSwesarr(flight_path=x_band, band='x')
x_example_raster = x_example.get_swesarr_raster()
x_example_raster
# Out:
# <xarray.DataArray (band: 1, y: 3651, x: 2963)>
# dask.array<open_rasterio-a67f8633b3ab40f052dae03e62f680e5<this-array>, shape=(1, 3651, 2963), dtype=float32, chunksize=(1, 1200, 1200), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) <U4 '09VH'
#   * x            (x) float64 7.412e+05 7.412e+05 ... 7.471e+05 7.471e+05
#   * y            (y) float64 4.328e+06 4.328e+06 4.328e+06 ... 4.32e+06 4.32e+06
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    nan
#     scale_factor:  1.0
#     add_offset:    0.0
